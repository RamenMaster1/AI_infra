# %%
import torch
import triton
import triton.language as tl

# %%
7//2
# Out:
# 3

# %%
a=torch.tensor([1,2,3])
b=torch.tensor([4,5,6])
print(a[:, None]*2)
print(b[None, :])
a[:, None]*2 + b[None, :]
# Out:
# tensor([[2],
#         [4],
#         [6]])
# tensor([[4, 5, 6]])
# tensor([[ 6,  7,  8],
#         [ 8,  9, 10],
#         [10, 11, 12]])

# %%
assert 1==1, "矩阵维度不匹配，无法相乘"

# %%
import torch
offs_m=torch.Tensor([1,2,3,4])
current_k_offsets=torch.Tensor([5,6,7,8])
(offs_m[:, None] < 3) & (current_k_offsets[None, :] < 6)
# Out:
# tensor([[ True, False, False, False],
#         [ True, False, False, False],
#         [False, False, False, False],
#         [False, False, False, False]])
