# %%
import torch 
import triton
import triton.language as tl
import numpy as np

# %%
x=torch.tensor([1,2,3,4,5,6])
torch.empty_like(x)
# Out:
# tensor([       11267680, 139968411894048, 139963707479664, 139963852044592,
#         139963851987888, 139968487092016])
