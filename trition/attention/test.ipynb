# %%
import torch

mask_matrix=torch.tril(torch.ones(3,3))
a=torch.randn(3,3)
a=a.masked_fill(mask_matrix==1,float('-inf'))
a
# Out:
# tensor([[      -inf, 1.0189e-03, 1.2305e+00],
#         [      -inf,       -inf, 5.4534e-01],
#         [      -inf,       -inf,       -inf]])

# %%
b=torch.int(1024)
b=torch.sqrt(torch.Tensor([1024]))
# Out:
# tensor([32.])

# %%
b.to(dtype=torch.float32)
b
# Out:
# tensor([32.])

# %%
c=torch.randint(1024,(1,))
d=torch.sqrt(c)
d.type()
# Out:
# 'torch.FloatTensor'

# %%
a=1
type(a)
# Out:
# tensor([6.0117e-32])

# %%
t3 = torch.tensor(3, dtype=torch.float32) 
t3
# Out:
# tensor(3.)

# %%
import math
a=torch.Tensor([1,2,3])
a-1
# math.exp(a-1)/10
# Out:
# tensor([0., 1., 2.])

# %%
torch.exp(a-1)/10
# Out:
# tensor([0.1000, 0.2718, 0.7389])

# %%
Q=torch.randn(5,768)
seq_len,embed_dim=Q.shape
print(seq_len,embed_dim)
# Out:
# 5 768

# %%
a=float("-inf")
b=torch.Tensor([1])
b.item()
max(a,b)
# Out:
# tensor([1.])

# %%
(6+3-1)//3
# Out:
# 2

# %%
import torch
a=torch.Tensor([[[1],[2],[3]]])
a
# Out:
# tensor([[[1.],
#          [2.],
#          [3.]]])

# %%
X=torch.Tensor([[1,2,3,4],[0,0,1,1],[1,1,2,2]])
b=torch.maximum(a, X)
print(b.shape)
print(b)
# Out:
# torch.Size([1, 3, 4])
# tensor([[[1., 2., 3., 4.],
#          [2., 2., 2., 2.],
#          [3., 3., 3., 3.]]])

# %%
c=torch.max(b,dim=2)
c.values[0]
# Out:
# tensor([4., 2., 3.])

# %%
torch.ones(4)*float("-inf")
# Out:
# tensor([-inf, -inf, -inf, -inf])

# %%
e=torch.Tensor([1.,2.,3.])
e
# Out:
# tensor([1., 2., 3.])

# %%
f=torch.stack([c.values[0], e], dim=0)
f
# Out:
# tensor([[4., 2., 3.],
#         [1., 2., 3.]])

# %%
torch.max(f,dim=0)
# Out:
# torch.return_types.max(
# values=tensor([4., 2., 3.]),
# indices=tensor([0, 0, 0]))

# %%
a=torch.Tensor([[1],[2],[3]])
a
# Out:
# tensor([[1.],
#         [2.],
#         [3.]])

# %%
b=torch.Tensor([[1,2],[2,3],[3,4]])
b-a
# Out:
# tensor([[0., 1.],
#         [0., 1.],
#         [0., 1.]])

# %%
a=a.view(1,3)
a
# Out:
# tensor([[1., 2., 3.]])

# %%
a.size()
# Out:
# torch.Size([3, 1])

# %%
torch.empty((2,3))
# Out:
# tensor([[2.4324e-31, 0.0000e+00, 0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00]])
